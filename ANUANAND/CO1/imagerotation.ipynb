# %%
import numpy as np
from PIL import Image
from scipy import ndimage
from matplotlib import pyplot as plt
a=Image.open('dog.jpg')
b=np.array(a)
c=ndimage.rotate(b,180)
plt.imshow(c)

# %%
z=ndimage.zoom(b,5.1)
d=Image.fromarray(z)
plt.imshow(d)
