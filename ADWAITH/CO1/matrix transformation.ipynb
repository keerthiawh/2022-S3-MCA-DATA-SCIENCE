# %%
import numpy as np
from scipy import ndimage
from PIL import Image
from matplotlib import pyplot as plt
a=Image.open('lion.jpg')
ar=np.array(a)
image=ndimage.rotate(ar,170)
plt.imshow(image)

# %%
import numpy as np
from scipy import ndimage
from PIL import Image
from matplotlib import pyplot as plt
a=Image.open('lion.jpg')
ar=np.array(a)
img=ndimage.zoom(ar,1.5)
plt.imshow(img)
