# %%
import numpy as np
from scipy import ndimage
from matplotlib import pyplot as plt
from PIL import Image
a=Image.open('download.jpg')
b=np.array(a)
plt.imshow(a)

# %%
x=ndimage.rotate(b,500,cval=20,reshape=True)
d=Image.fromarray(x)
plt.imshow(d)

# %%
a=Image.open('download.jpg')
b=np.array(a)
plt.imshow(b)

# %%
import numpy as np
from scipy import ndimage
from matplotlib import pyplot as plt
from PIL import Image
a=Image.open('images.jpg')
b=np.array(a)
x=ndimage.zoom(b,1.2)
d=Image.fromarray(x)
plt.imshow(d)

# %%
import numpy as np
from scipy import ndimage
from matplotlib import pyplot as plt
from PIL import Image
a=Image.open('images.jpg')
scipy.ndimage.affine_transform(a, matrix, offset=0.0, output_shape=None, output=None, order=3, mode='constant', cval=0.0, prefilter=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4360/3509466691.py in <module>
#       4 from PIL import Image
#       5 a=Image.open('images.jpg')
# ----> 6 scipy.ndimage.affine_transform(a, matrix, offset=0.0, output_shape=None, output=None, order=3, mode='constant', cval=0.0, prefilter=True)
#
# NameError: name 'scipy' is not defined
