# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import ndimage
from PIL import Image
b = Image.open('marvel.jpg')
plt.imshow(b)

# %%
import numpy as np
from scipy import ndimage
from matplotlib import pyplot as plt
from PIL import Image
a=Image.open('marvel.jpg')
plt.imshow(a)
b=np.array(a)
x=ndimage.rotate(b,180)
plt.imshow(x)

# %%
y=ndimage.zoom(b,(.25,.25,1))
w=Image.fromarray(y)
plt.imshow(w)
