# %%
from matplotlib import pyplot as plt
import numpy as np
x=np.arange(0,20,0.2)
y=np.sin(x)
plt.subplot(1,3,1)
plt.plot(x,y)


x=np.arange(0,20,0.2)
y=np.cos(x)
plt.subplot(1,3,2)
plt.plot(x,y)

x=np.arange(0,20,0.2)
y=np.tan(x)
plt.subplot(1,3,3)
plt.plot(x,y)
