# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import ndimage
from PIL import Image
b=Image.open('Red_Kitten_01.jpg')
plt.imshow(b)

# %%
a=np.array(b)
c=ndimage.rotate(a,180)
plt.imshow(c)

# %%
c=ndimage.zoom(a,(0.99,0.99,1))
plt.imshow(c)
