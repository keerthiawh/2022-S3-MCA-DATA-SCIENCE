# %%
import matplotlib.pyplot as plt
x=[2,5,7,8]
y=[6,4,2,9]
plt.plot(x,y, label="line1" , color="green")
x=[4,7,3,8]
y=[3,7,9,2]
plt.plot(x,y,label="line2", color="pink")
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('linear graph')
plt.legend()
plt.show()
