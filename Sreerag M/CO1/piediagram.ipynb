# %%
import matplotlib.pyplot as plt
import numpy as np

M = np.array([35, 25, 25, 15,50,40])
mylabels = ["AOS", "ADS", "JAVA", "PYTHON","HTML","DSM"]
myexplode = [ 0, 0, 0, 0,0,0.2]
plt.pie(M,labels = mylabels, explode= myexplode)
plt.show()
