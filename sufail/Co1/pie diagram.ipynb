# %%
import matplotlib.pyplot as plt
subjects = ['math','science','english','history','art','music']
marks = [85,33,45,77,88,26]
ex=(0,0.1,0,0,0,0)
plt.pie(marks,labels=subjects,explode=ex)
plt.title('students mark in 6 subjects')
plt.show()
