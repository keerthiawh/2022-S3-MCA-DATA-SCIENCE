# %%
import numpy as np
from scipy import ndimage
from matplotlib import pyplot as plt
from PIL import Image
a=Image.open('jerry.jpg')
plt.imshow(a)
b=np.array(a)
x=ndimage.rotate(b,360)
plt.imshow(x)

# %%
y=ndimage.zoom(b,(.25,.25,1))
w=Image.fromarray(y)
plt.imshow(w)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7352/937152735.py in <module>
# ----> 1 y=ndimage.zoom(b,(.25,.25,1))
#       2 w=Image.fromarray(y)
#       3 plt.imshow(w)
#
# NameError: name 'ndimage' is not defined

# %%
y=ndImage.zoom(b,(.25,.25,1))
w=Image.fromarray(y)
plt.imshow(w)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7352/2251351708.py in <module>
# ----> 1 y=ndImage.zoom(b,(.25,.25,1))
#       2 w=Image.fromarray(y)
#       3 plt.imshow(w)
#
# NameError: name 'ndImage' is not defined

# %%
y=ndimage.zoom(b,(.25,.25,1))
w=Image.fromarray(y)
plt.imshow(w)
