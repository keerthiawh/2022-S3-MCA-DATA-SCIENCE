# %%
#simple plot
from matplotlib import pyplot as plt
x=[6,8,2,9]
y=[7,3,10,7]
plt.plot(x,y)
plt.show()

# %%
#bar plot
x=['Ajin','Akash','Hani']
y=[6,9,6]
plt.bar(x,y,color='pink')
plt.xlabel("name")
plt.ylabel("marks")
# Out:
# Text(0, 0.5, 'marks')
