# %%
#image in array
import numpy as np
from PIL import Image
from scipy import ndimage
from matplotlib import pyplot as plt 
a=Image.open('image.png')
b=np.array(a)
plt.imshow(a)

# %%
#zoom Image
y=ndimage.zoom(b,(0.4,0.4,1))
n=Image.fromarray(y)
plt.imshow(n)

# %%
#Rotate image
rotate_arr=ndimage.rotate(im_arr,142)
plt.imshow(rotate_arr)
