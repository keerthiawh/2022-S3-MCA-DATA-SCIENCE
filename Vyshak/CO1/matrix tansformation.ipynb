# %%
import numpy as np
from PIL import Image
from scipy import ndimage
from matplotlib import pyplot as plt
img=Image.open("ss.png")
plt.imshow(img)
a=np.array(img)
b=ndimage.rotate(a,180)
plt.imshow(b)

# %%
z=ndimage.zoom(b,(1.2,1.2,1))
d=Image.fromarray(z)
plt.imshow(d)
