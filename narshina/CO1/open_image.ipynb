# %% [markdown]
# import numpy as np
# from PIL import image
# from scipy import ndimage
# from matplot.lib pyplot as plt

# %%
import numpy as np 
from PIL import Image
from scipy import ndimage
from matplotlib import pyplot as plt
a=Image.open('flower.jpj')
plt.imshow(a)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9712/4260761823.py in <module>
#       3 from scipy import ndimage
#       4 from matplotlib import pyplot as plt
# ----> 5 a=Image.open('flower.jpj')
#       6 plt.imshow(a)
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# FileNotFoundError: [Errno 2] No such file or directory: 'flower.jpj'

# %%
import numpy as np 
from PIL import Image
from scipy import ndimage
from matplotlib import pyplot as plt
a=Image.open('flower.jpg')
plt.imshow(a)

# %%
import numpy as np 
from PIL import Image
from scipy import ndimage
from matplotlib import pyplot as plt
a=Image.open('flower.jpg')
plt.imshow(a)
b=np.array(a)
x=ndimage.rotate(b,90)
d=Image.fromarray(x)
plt.imshow(d)

# %%
y=ndimage.zoom(b,(.25,.25,1))
w=Image.fromarray(y)
plt.imshow(w)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5204/937152735.py in <module>
# ----> 1 y=ndimage.zoom(b,(.25,.25,1))
#       2 w=Image.fromarray(y)
#       3 plt.imshow(w)
#
# NameError: name 'ndimage' is not defined

# %%
y=ndimage.zoom(b,(.25,.25,1))
w=Image.fromarray(y)
plt.imshow(w)
