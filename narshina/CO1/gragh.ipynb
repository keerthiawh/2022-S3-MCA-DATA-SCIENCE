# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.array([1,2])
y=np.array([3,10])

plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.random.normal(170,10,250)

plt.hist(x)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

y=np.array([35,25,25,15])

plt.pie(y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()
