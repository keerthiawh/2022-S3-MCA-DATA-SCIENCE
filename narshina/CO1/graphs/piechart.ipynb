# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([78, 45, 55, 95, 80, 89])
mylabels = ["maths", "physics", "Chemistry", "botany","english", "hindi"]
explodes = [0, 0, 0, 0.2, 0, 0]

plt.pie(y, labels = mylabels, explode=explodes)
plt.show()
