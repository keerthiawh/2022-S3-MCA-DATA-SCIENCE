# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[1,4,9,16]
plt.subplot(1,3,1)
plt.plot(x,y)

x=[1,2,3,4]
y=[3,5,6,8]
plt.subplot(1,3,2)
plt.plot(x,y)

x=[1,2,3,4]
y=[7,5,3,2]
plt.subplot(1,3,3)
plt.plot(x,y)
