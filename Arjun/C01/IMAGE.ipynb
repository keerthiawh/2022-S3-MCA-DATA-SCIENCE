# %%
print("PYCHARM")
# Out:
# PYCHARM

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import ndimage
from PIL import Image 
e = Image.open('ambani.jpg')
plt.imshow(e)

z = np.array(e)
# a = e.rotate(180)
# plt.imshow(a)

# %%
x = ndimage.rotate(z,90)
plt.imshow(x)

# %%
h = ndimage.zoom(e,(0.5,0.5,1))
w = Image.fromarray(h)
plt.imshow(w)
