# %%
import numpy as np
from scipy import ndimage
from matplotlib import pyplot as plt
from PIL import Image
a=Image.open('images.jpg')
print(a)
plt.imshow(a)
b=np.array(a)
x= ndimage.rotate(b,90)
plt.imshow(x)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x26B706D12B0>

# %%
y=ndimage.zoom(b,(.25,.25,1))
w=Image.fromarray(y)
plt.imshow(w)

# %%
import numpy as np
from scipy import ndimage
from matplotlib import pyplot as plt
from PIL import Image
a=Image.open('images.jpg')
print(a)
plt.imshow(a)
b=np.array(a)
x= ndimage.rotate(b,90)
plt.imshow(x)
img1 = ndimage.affinetransformation(a, b)
plt.imshow(img1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x266D627CD60>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\AWH23~1\AppData\Local\Temp/ipykernel_13212/3057648735.py in <module>
#       9 x= ndimage.rotate(b,90)
#      10 plt.imshow(x)
# ---> 11 img1 = ndimage.affinetransformation(a, b)
#      12 plt.imshow(img1)
#
# AttributeError: module 'scipy.ndimage' has no attribute 'affinetransformation'
